# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt

# %%
times=np.linspace(0.0,10.0,200)
psi0=tensor(fock(2,0),fock(10,5))
a=tensor(qeye(2),destroy(10))
sm=tensor(destroy(2),qeye(10))
H=2*np.pi*a.dag()*a+2*np.pi*sm.dag()*sm+2*np.pi*0.25*(sm*a.dag()+sm.dag()*a)

# %%
data=mcsolve(H,psi0,times,[np.sqrt(0.1)*a],[a.dag()*a,sm.dag()*sm])
# Out:
# 10.0%. Run time:   2.87s. Est. time left: 00:00:00:25
# 20.0%. Run time:   3.18s. Est. time left: 00:00:00:12
# 30.0%. Run time:   3.48s. Est. time left: 00:00:00:08
# 40.0%. Run time:   3.77s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.06s. Est. time left: 00:00:00:04
# 60.0%. Run time:   4.38s. Est. time left: 00:00:00:02
# 70.0%. Run time:   4.66s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.94s. Est. time left: 00:00:00:01
# 90.0%. Run time:   5.25s. Est. time left: 00:00:00:00
# 100.0%. Run time:   5.52s. Est. time left: 00:00:00:00
# Total run time:   5.67s

# %%
plt.figure()

# %%
plt.plot(times,data.expect[0],times,data.expect[1])
plt.xlabel('Time')
plt.ylabel('Expectation values')
plt.legend(('cavity photon number','atom excitation probability'))

# %%
qsave(data,'cavity.dat')
